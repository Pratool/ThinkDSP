# %%
# %matplotlib inline
import sys
import os
sys.path.append(os.path.abspath("../code/"))
import thinkdsp
import thinkplot
import numpy
import math
import types #to append methods to classes

# %% [markdown]
# 1) Run and listen to the examples in chap03.ipynb.  In the leakage example, try replacing the Hamming window with one of the other windows provided by NumPy, and see what effect they have on leakage. See http://docs.scipy.org/doc/numpy/reference/routines.window.html

# %%
sin_wave = thinkdsp.SinSignal(freq=440, amp=1.0).make_wave(duration=(2.0/440)+0.01, start=0)
sin_wave.plot()

# %%
sin_wave.make_spectrum().plot()

# %%
sin_wave.hamming()
sin_wave.plot()

# %%
sin_wave.make_spectrum().plot()

# %% [markdown]
# Added the following code to implement a Kaiser window.

# %%
def kaiser(self, beta):
    """Apply the Kaiser window to the wave.
    """
    self.ys *= numpy.kaiser(len(self.ys), beta)

# %%
sin_wave = thinkdsp.SinSignal(freq=440, amp=1.0).make_wave(duration=(2.0/440)+0.01, start=0)
sin_wave.plot()

# %%
sin_wave.kaiser = types.MethodType( kaiser, sin_wave )
sin_wave.kaiser(14)
sin_wave.plot()

# %%
sin_wave.make_spectrum().plot()

# %% [markdown]
# 2) Write a class called SawtoothChirp that extends Chirp and overrides evaluate to generate a sawtooth waveform with frequency that increases (or decreases) linearly.
#
# Hint: combine the evaluate functions from Chirp and SawtoothSignal.
#
# Plot the spectrogram of this signal. The effect of aliasing should be visible, and if you listen carefully, you can hear it.

# %%
class SawtoothChirp(thinkdsp.Chirp):
    """Represents a sawtooth signal with varying frequency."""
    
    def evaluate(self, ts):
        """Evaluates the signal at the given times.

        ts: float array of times
        
        returns: float wave array
        """
        freqs = numpy.linspace(self.start, self.end, len(ts)-1)
        return self._evaluate(ts, freqs)
    
    def _evaluate(self, ts, freqs):
        """Helper function that evaluates the signal.

        ts: float array of times
        freqs: float array of frequencies during each interval
        """
        dts = numpy.diff(ts)
        dps = 2 * numpy.pi * freqs * dts
        phases = numpy.cumsum(dps)
        phases = numpy.insert(phases, 0, 0)
        cycles = phases / (2*numpy.pi)
        frac,_ = numpy.modf(cycles)
        
        # normalize (divide through by the largest value)
        ys = frac / max(frac)
        
        # unbias (make mean = 0 (subtract by mean))
        ys = ys - ys.mean()
        
        # make sure amplitude is right
        ys = self.amp * ys
        return ys

# %%
signal = SawtoothChirp()
wave1 = signal.make_wave(duration=2)
wave1.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave1.segment(start=0, duration=0.01).plot()

# %%
wave1.segment(start=1.5, duration=0.01).plot()

# %%
spectrogram = wave1.make_spectrogram(seg_length=512)
spectrogram.plot()

# %% [markdown]
# Discuss the spectrogram and stuff. The aliasing is apparent in the spectrogram as the "negative slope" lines that cross the "positive slope" lines (which are the harmonics).

# %% [markdown]
# 3)  In musical terminology, a “glissando” is a note that slides from one pitch to another, so it is similar to a chirp. A trombone player can play a glissando by extending the trombone slide while blowing continuously. As the slide extends, the total length of the tube gets longer, and the resulting pitch is inversely proportional to length.
#
# Assuming that the player moves the slide at a constant speed, how does frequency vary with time? Is a trombone glissando more like a linear or exponential chirp?
#
# Write a function that simulates a trombone glissando from C3 up to F3 and back down to C3. C3 is 262 Hz; F3 is 349 Hz.

# %% [markdown]
# A trombone glissando is more like an exponential chirp. If the tube is pulled in at constant velocity, the pitch is then directly proportional to time. Audible pitch that increases linearly actually has an exponential increase in frequency.

# %%
g1 = thinkdsp.ExpoChirp(start=262, end=349, amp=1.0).make_wave(start=0, duration=1)
g2 = thinkdsp.ExpoChirp(start=349, end=262, amp=1.0).make_wave(start=0, duration=1)
g1.apodize()
g2.apodize()
gliss = g1|g2
gliss.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gliss.make_spectrogram(seg_length=1024).plot(high=64)

# %% [markdown]
# 4) Make or find a recording of a series of vowel sounds and look at the spectrogram. Can you identify different vowels?

# %%
a_vowel = thinkdsp.read_wave('a-vowel.wav')
a_vowel = a_vowel.segment(start=0, duration=0.5)
a_vowel.apodize()
a_vowel.make_spectrogram(seg_length=512).plot(high=16)
a_vowel.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a_vowel.plot()

# %%
e_vowel = thinkdsp.read_wave('e-vowel.wav')
e_vowel = e_vowel.segment(start=0, duration=0.5)
e_vowel.apodize()
e_vowel.make_spectrogram(seg_length=512).plot(high=16)
e_vowel.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
e_vowel.plot()

# %%
o_vowel = thinkdsp.read_wave('o-vowel.wav')
o_vowel = o_vowel.segment(start=0, duration=0.5)
o_vowel.apodize()
o_vowel.make_spectrogram(seg_length=512).plot(high=16)
o_vowel.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
o_vowel.plot()

# %%
u_vowel = thinkdsp.read_wave('u-vowel.wav')
u_vowel = u_vowel.segment(start=0, duration=0.5)
u_vowel.apodize()
u_vowel.make_spectrogram(seg_length=512).plot(high=16)
u_vowel.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
u_vowel.plot()

# %% [markdown]
# The harmonics are

# %% [markdown]
# 5) “A Soft Murmur” is a web site that plays a mixture of natural noise sources, including rain, waves, wind, etc. At http://asoftmurmur.com/about/ you can find their list of recordings, most of which are at http://freesound.org.
#
# Download a few of these files and compute the spectrum of each signal. Does the power spectrum look like white noise, pink noise, or Brownian noise? How does the spectrum vary over time?

# %%
soarer = thinkdsp.read_wave('soarer-north-sea-clip.wav')
soarer.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
soarer_spec = soarer.make_spectrum()
thinkplot.preplot(1)
soarer_spec.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power density',
                 xscale='log',
                 yscale='log',
                 legend=False)

# %%
soarer.make_spectrogram(seg_length=512).plot(high=16)

# %%
def bartlett(divisor, wave):
    '''
    Inputs:
        divisor- the number of pieces to divide the time signal into
        wave- the input wave to perform the bartlett method on
    
    Output:
        avg_spec- the spectrum object output that is the multiple-sample average
    '''
    dv = len(wave.ys)/divisor
    broken = []
    for i in range(divisor):
        r = thinkdsp.Wave(wave.ys[i*dv:(i+1)*dv], 11025).make_spectrum()
        broken.append( abs(r.hs)**2 / dv )
    avg = broken[0]*0
    for i in range(divisor):
        avg = avg + broken[i]
    avg = avg / divisor
    avg_spec = thinkdsp.Spectrum(avg, 11025)
    return avg_spec

avg_spec = bartlett(15, soarer)
avg_spec.plot()

# %%
soarer.make_spectrum().plot()

# %%
thinkplot.preplot(1)
avg_spec.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                 ylabel='power density',
                 xscale='log',
                 yscale='log',
                 legend=False)
